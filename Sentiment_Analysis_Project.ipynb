# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.19.4-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 7.3 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 59.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 73.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.4

# %%
import pandas as pd
import torch
import torch.nn as nn
from transformers import  BertModel, BertTokenizer
from torch.utils.data import DataLoader
import torch.optim as optim
import os
from torch.utils.data import Dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Train-test split

# %%
path_csv = "/content/drive/MyDrive/Reviews.csv"
df=pd.read_csv(path_csv)
df=df[["Score","Text"]]
df
# Out:
#         Score                                               Text
# 0           5  I have bought several of the Vitality canned d...
# 1           1  Product arrived labeled as Jumbo Salted Peanut...
# 2           4  This is a confection that has been around a fe...
# 3           2  If you are looking for the secret ingredient i...
# 4           5  Great taffy at a great price.  There was a wid...
# ...       ...                                                ...
# 568449      5  Great for sesame chicken..this is a good if no...
# 568450      2  I'm disappointed with the flavor. The chocolat...
# 568451      5  These stars are small, so you can give 10-15 o...
# 568452      5  These are the BEST treats for training and rew...
# 568453      5  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
train, rem = train_test_split(df, test_size=0.9)
test_val,rem = train_test_split(rem, test_size=0.9)
test,val = train_test_split(test_val, test_size=0.5)

# %%
train.Score.value_counts()
# Out:
# 5    36210
# 4     8074
# 1     5235
# 3     4305
# 2     3021
# Name: Score, dtype: int64

# %% [markdown]
# There is class imbalance, hence we do some preprocessing to remove the imbalance

# %%
from sklearn.utils import shuffle
train = shuffle(train)
test = shuffle(test)
val = shuffle(val)

# %%
len(train)
# Out:
# 56845

# %% [markdown]
# ## Loading tokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='bert-base-uncased', vocab_size=30522, model_max_len=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %% [markdown]
# ## Preprocessing to deal with class imbalance

# %% [markdown]
# We split each review into text of upto 50 words and then perform undersampling

# %%
def remove_imbalance(df):
  dfnew=shuffle(df)
  num_each = dfnew.Score.value_counts().values[-1]

  df1 = dfnew[dfnew["Score"]==1].sample(num_each)
  df2 = dfnew[dfnew["Score"]==2].sample(num_each)
  df3 = dfnew[dfnew["Score"]==3].sample(num_each)
  df4 = dfnew[dfnew["Score"]==4].sample(num_each)
  df5 = dfnew[dfnew["Score"]==5].sample(num_each)
  dfs = [df1,df2,df3,df4,df5]
  df = pd.concat(dfs)
  df=shuffle(df)
  return df

# %%
train = remove_imbalance(train)
test = remove_imbalance(test)
val = remove_imbalance(val)

# %%
len(train)
# Out:
# 15105

# %% [markdown]
# ## Applying the Bert tokenizer

# %%
class Preprocess(Dataset):
    def __init__(self, df, maxlen=512):
        df.reset_index(drop=True, inplace=True)
        self.df = df
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
        self.maxlen = maxlen

    def __len__(self):
        return(len(self.df))

    def __getitem__(self, index):
        review = self.df.loc[index, 'Text']

        # Classes start from 0.
        label = int(self.df.loc[index, 'Score']) - 1

        # Use BERT tokenizer since it needs to be able to match the tokens to the pre trained words.
        encoded = self.tokenizer.encode_plus(
        text=review,  # the sentence to be encoded
        add_special_tokens=True,  # Add [CLS] and [SEP]
        max_length = self.maxlen,  # maximum length of a sentence
        truncation=True,
        pad_to_max_length=True,  # Add [PAD]s
        return_attention_mask = True,  # Generate the attention mask
        return_tensors = 'pt',  # ask the function to return PyTorch tensors
        )

        tokens_ids_tensor = encoded['input_ids']
        attn_mask = encoded['attention_mask']

        return tokens_ids_tensor, attn_mask, label

# %%
train_set = Preprocess(train)
val_set = Preprocess(val)
test_set = Preprocess(test)

# %% [markdown]
# ## Data loaders

# %%
train_loader = DataLoader(train_set, batch_size = 64)
val_loader = DataLoader(val_set, batch_size = 64)
test_loader = DataLoader(test_set, batch_size = 64)

# %% [markdown]
# ## Defining NN class

# %%
class SentimentModel(nn.Module):
    def __init__(self, device, num_classes=5, freeze_bert = True):
        super(SentimentModel, self).__init__()
        self.bert_layer = BertModel.from_pretrained('bert-base-uncased')
        self.device = device

        if freeze_bert:
            for p in self.bert_layer.parameters():
                p.requires_grad = False

        self.final_layer = nn.Linear(768, num_classes)

    def forward(self, seq, attn_masks):

        cont_reps = self.bert_layer(seq, attention_mask = attn_masks)
        cls_rep = cont_reps[0][:,0]
        logits = self.final_layer(cls_rep)
        return logits.to(self.device)

# %%
net = SentimentModel(device, freeze_bert=True)
net.to(device)
# Out:
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# SentimentModel(
#   (bert_layer): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (final_layer): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
loss_func = nn.CrossEntropyLoss()
opti = optim.Adam(net.parameters(), lr = 2e-4)

# %% [markdown]
# ## Training

# %%
def get_accuracy(logits, labels):
    predictedClass = logits.max(dim = 1)[1]
    acc = (predictedClass == labels).float().mean()
    return acc

# %%
def trainFunc(net, loss_func, opti, train_loader, test_loader, epochs, printEvery):
    for ep in range(epochs):
        print("EPOCH: ", ep+1)
        for it, (seq, attn_masks, labels) in enumerate(train_loader):
            opti.zero_grad()
            seq, attn_masks, labels = seq.to(device), attn_masks.to(device), labels.to(device)
      
            logits = net(seq[:,0,:], attn_masks[:,0,:])
            loss = loss_func(logits, labels)

            loss.backward()
            opti.step()

            if (it + 1) % printEvery == 0:
                acc = get_accuracy(logits, labels)

                print("Iteration {} of epoch {} complete. Loss : {} Accuracy : {}".format(it+1, ep+1, loss.item(), acc))

        # Perform validation at the end of an epoch.
        val_acc, val_loss = evaluate(net, loss_func, val_loader)
        print(" Validation Accuracy : {}, Validation Loss : {}".format(val_acc, val_loss))

# %%
def evaluate(net, loss_func, dataloader):
    net.eval()

    mean_acc, mean_loss = 0, 0
    count = 0

    with torch.no_grad():
        for seq, attn_masks, labels in dataloader:
            seq, attn_masks, labels = seq.to(device), attn_masks.to(device), labels.to(device)

            logits = net(seq[:,0,:], attn_masks[:,0,:])
            mean_loss += loss_func(logits, labels)
            mean_acc += get_accuracy(logits, labels)
            count += 1
    return mean_acc / count, mean_loss / count

# %%
trainFunc(net, loss_func, opti, train_loader, test_loader, epochs=10, printEvery=10)
# Out:
# EPOCH:  1
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2291: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Iteration 10 of epoch 1 complete. Loss : 1.671596884727478 Accuracy : 0.1875
# Iteration 20 of epoch 1 complete. Loss : 1.6141927242279053 Accuracy : 0.140625
# Iteration 30 of epoch 1 complete. Loss : 1.596872329711914 Accuracy : 0.265625
# Iteration 40 of epoch 1 complete. Loss : 1.594351887702942 Accuracy : 0.234375
# Iteration 50 of epoch 1 complete. Loss : 1.5954415798187256 Accuracy : 0.21875
# Iteration 60 of epoch 1 complete. Loss : 1.5486068725585938 Accuracy : 0.3125
# Iteration 70 of epoch 1 complete. Loss : 1.5628129243850708 Accuracy : 0.390625
# Iteration 80 of epoch 1 complete. Loss : 1.5889497995376587 Accuracy : 0.296875
# Iteration 90 of epoch 1 complete. Loss : 1.5475162267684937 Accuracy : 0.3125
# Iteration 100 of epoch 1 complete. Loss : 1.512465000152588 Accuracy : 0.40625
# Iteration 110 of epoch 1 complete. Loss : 1.5212379693984985 Accuracy : 0.359375
# Iteration 120 of epoch 1 complete. Loss : 1.453666090965271 Accuracy : 0.515625
# Iteration 130 of epoch 1 complete. Loss : 1.5468827486038208 Accuracy : 0.296875
# Iteration 140 of epoch 1 complete. Loss : 1.464862585067749 Accuracy : 0.390625
# Iteration 150 of epoch 1 complete. Loss : 1.5045888423919678 Accuracy : 0.390625
# Iteration 160 of epoch 1 complete. Loss : 1.486870527267456 Accuracy : 0.390625
# Iteration 170 of epoch 1 complete. Loss : 1.4541616439819336 Accuracy : 0.46875
# Iteration 180 of epoch 1 complete. Loss : 1.4358197450637817 Accuracy : 0.484375
# Iteration 190 of epoch 1 complete. Loss : 1.39938485622406 Accuracy : 0.46875
# Iteration 200 of epoch 1 complete. Loss : 1.4473576545715332 Accuracy : 0.375
# Iteration 210 of epoch 1 complete. Loss : 1.4095611572265625 Accuracy : 0.546875
# Iteration 220 of epoch 1 complete. Loss : 1.450236201286316 Accuracy : 0.40625
# Iteration 230 of epoch 1 complete. Loss : 1.399814486503601 Accuracy : 0.5
#  Validation Accuracy : 0.41409340500831604, Validation Loss : 1.436707615852356
# EPOCH:  2
# Iteration 10 of epoch 2 complete. Loss : 1.4953807592391968 Accuracy : 0.28125
# Iteration 20 of epoch 2 complete. Loss : 1.4027128219604492 Accuracy : 0.453125
# Iteration 30 of epoch 2 complete. Loss : 1.4382503032684326 Accuracy : 0.4375
# Iteration 40 of epoch 2 complete. Loss : 1.4238585233688354 Accuracy : 0.46875
# Iteration 50 of epoch 2 complete. Loss : 1.4649968147277832 Accuracy : 0.390625
# Iteration 60 of epoch 2 complete. Loss : 1.3330192565917969 Accuracy : 0.5
# Iteration 70 of epoch 2 complete. Loss : 1.4538652896881104 Accuracy : 0.390625
# Iteration 80 of epoch 2 complete. Loss : 1.469689965248108 Accuracy : 0.40625
# Iteration 90 of epoch 2 complete. Loss : 1.4398281574249268 Accuracy : 0.328125
# Iteration 100 of epoch 2 complete. Loss : 1.3836902379989624 Accuracy : 0.390625
# Iteration 110 of epoch 2 complete. Loss : 1.3710917234420776 Accuracy : 0.4375
# Iteration 120 of epoch 2 complete. Loss : 1.286117672920227 Accuracy : 0.578125
# Iteration 130 of epoch 2 complete. Loss : 1.4409328699111938 Accuracy : 0.359375
# Iteration 140 of epoch 2 complete. Loss : 1.343886375427246 Accuracy : 0.4375
# Iteration 150 of epoch 2 complete. Loss : 1.4015069007873535 Accuracy : 0.40625
# Iteration 160 of epoch 2 complete. Loss : 1.3756108283996582 Accuracy : 0.40625
# Iteration 170 of epoch 2 complete. Loss : 1.33196222782135 Accuracy : 0.453125
# Iteration 180 of epoch 2 complete. Loss : 1.3049147129058838 Accuracy : 0.5625
# Iteration 190 of epoch 2 complete. Loss : 1.2676624059677124 Accuracy : 0.4375
# Iteration 200 of epoch 2 complete. Loss : 1.3393205404281616 Accuracy : 0.40625
# Iteration 210 of epoch 2 complete. Loss : 1.3224868774414062 Accuracy : 0.578125
# Iteration 220 of epoch 2 complete. Loss : 1.363461971282959 Accuracy : 0.40625
# Iteration 230 of epoch 2 complete. Loss : 1.3022913932800293 Accuracy : 0.515625
#  Validation Accuracy : 0.4425172805786133, Validation Loss : 1.354745864868164
# EPOCH:  3
# Iteration 10 of epoch 3 complete. Loss : 1.4203379154205322 Accuracy : 0.3125
# Iteration 20 of epoch 3 complete. Loss : 1.309352159500122 Accuracy : 0.5
# Iteration 30 of epoch 3 complete. Loss : 1.3589248657226562 Accuracy : 0.453125
# Iteration 40 of epoch 3 complete. Loss : 1.350435733795166 Accuracy : 0.5
# Iteration 50 of epoch 3 complete. Loss : 1.4120205640792847 Accuracy : 0.46875
# Iteration 60 of epoch 3 complete. Loss : 1.2356799840927124 Accuracy : 0.46875
# Iteration 70 of epoch 3 complete. Loss : 1.4072928428649902 Accuracy : 0.4375
# Iteration 80 of epoch 3 complete. Loss : 1.4069342613220215 Accuracy : 0.421875
# Iteration 90 of epoch 3 complete. Loss : 1.3894917964935303 Accuracy : 0.359375
# Iteration 100 of epoch 3 complete. Loss : 1.3280808925628662 Accuracy : 0.421875
# Iteration 110 of epoch 3 complete. Loss : 1.2951016426086426 Accuracy : 0.453125
# Iteration 120 of epoch 3 complete. Loss : 1.2059394121170044 Accuracy : 0.609375
# Iteration 130 of epoch 3 complete. Loss : 1.3865702152252197 Accuracy : 0.390625
# Iteration 140 of epoch 3 complete. Loss : 1.285510778427124 Accuracy : 0.4375
# Iteration 150 of epoch 3 complete. Loss : 1.351552128791809 Accuracy : 0.40625
# Iteration 160 of epoch 3 complete. Loss : 1.3213262557983398 Accuracy : 0.421875
# Iteration 170 of epoch 3 complete. Loss : 1.2740821838378906 Accuracy : 0.46875
# Iteration 180 of epoch 3 complete. Loss : 1.237955093383789 Accuracy : 0.5625
# Iteration 190 of epoch 3 complete. Loss : 1.197304606437683 Accuracy : 0.484375
# Iteration 200 of epoch 3 complete. Loss : 1.2831085920333862 Accuracy : 0.453125
# Iteration 210 of epoch 3 complete. Loss : 1.280576229095459 Accuracy : 0.5625
# Iteration 220 of epoch 3 complete. Loss : 1.3136614561080933 Accuracy : 0.40625
# Iteration 230 of epoch 3 complete. Loss : 1.248363733291626 Accuracy : 0.53125
#  Validation Accuracy : 0.4566253125667572, Validation Loss : 1.3111649751663208
# EPOCH:  4
# Iteration 10 of epoch 4 complete. Loss : 1.3780938386917114 Accuracy : 0.34375
# Iteration 20 of epoch 4 complete. Loss : 1.2574210166931152 Accuracy : 0.5
# Iteration 30 of epoch 4 complete. Loss : 1.3104194402694702 Accuracy : 0.484375
# Iteration 40 of epoch 4 complete. Loss : 1.3105332851409912 Accuracy : 0.5
# Iteration 50 of epoch 4 complete. Loss : 1.3831748962402344 Accuracy : 0.5
# Iteration 60 of epoch 4 complete. Loss : 1.1810903549194336 Accuracy : 0.484375
# Iteration 70 of epoch 4 complete. Loss : 1.3803613185882568 Accuracy : 0.421875
# Iteration 80 of epoch 4 complete. Loss : 1.367897629737854 Accuracy : 0.421875
# Iteration 90 of epoch 4 complete. Loss : 1.3601628541946411 Accuracy : 0.40625
# Iteration 100 of epoch 4 complete. Loss : 1.295691728591919 Accuracy : 0.515625
# Iteration 110 of epoch 4 complete. Loss : 1.2495946884155273 Accuracy : 0.46875
# Iteration 120 of epoch 4 complete. Loss : 1.1607558727264404 Accuracy : 0.59375
# Iteration 130 of epoch 4 complete. Loss : 1.3531800508499146 Accuracy : 0.4375
# Iteration 140 of epoch 4 complete. Loss : 1.2514299154281616 Accuracy : 0.46875
# Iteration 150 of epoch 4 complete. Loss : 1.3225059509277344 Accuracy : 0.4375
# Iteration 160 of epoch 4 complete. Loss : 1.2888233661651611 Accuracy : 0.453125
# Iteration 170 of epoch 4 complete. Loss : 1.2415149211883545 Accuracy : 0.46875
# Iteration 180 of epoch 4 complete. Loss : 1.1981264352798462 Accuracy : 0.546875
# Iteration 190 of epoch 4 complete. Loss : 1.153416633605957 Accuracy : 0.5625
# Iteration 200 of epoch 4 complete. Loss : 1.247646450996399 Accuracy : 0.484375
# Iteration 210 of epoch 4 complete. Loss : 1.2557618618011475 Accuracy : 0.5625
# Iteration 220 of epoch 4 complete. Loss : 1.2799454927444458 Accuracy : 0.40625
# Iteration 230 of epoch 4 complete. Loss : 1.2122571468353271 Accuracy : 0.53125
#  Validation Accuracy : 0.46785104274749756, Validation Loss : 1.2840596437454224
# EPOCH:  5
# Iteration 10 of epoch 5 complete. Loss : 1.3497309684753418 Accuracy : 0.328125
# Iteration 20 of epoch 5 complete. Loss : 1.2235908508300781 Accuracy : 0.484375
# Iteration 30 of epoch 5 complete. Loss : 1.2773761749267578 Accuracy : 0.484375
# Iteration 40 of epoch 5 complete. Loss : 1.2859973907470703 Accuracy : 0.5
# Iteration 50 of epoch 5 complete. Loss : 1.364626407623291 Accuracy : 0.5
# Iteration 60 of epoch 5 complete. Loss : 1.1459031105041504 Accuracy : 0.5
# Iteration 70 of epoch 5 complete. Loss : 1.3619320392608643 Accuracy : 0.40625
# Iteration 80 of epoch 5 complete. Loss : 1.3411661386489868 Accuracy : 0.4375
# Iteration 90 of epoch 5 complete. Loss : 1.3409188985824585 Accuracy : 0.375
# Iteration 100 of epoch 5 complete. Loss : 1.2732073068618774 Accuracy : 0.484375
# Iteration 110 of epoch 5 complete. Loss : 1.2197864055633545 Accuracy : 0.46875
# Iteration 120 of epoch 5 complete. Loss : 1.1324571371078491 Accuracy : 0.578125
# Iteration 130 of epoch 5 complete. Loss : 1.3305009603500366 Accuracy : 0.484375
# Iteration 140 of epoch 5 complete. Loss : 1.2289198637008667 Accuracy : 0.453125
# Iteration 150 of epoch 5 complete. Loss : 1.3032336235046387 Accuracy : 0.4375
# Iteration 160 of epoch 5 complete. Loss : 1.2667553424835205 Accuracy : 0.4375
# Iteration 170 of epoch 5 complete. Loss : 1.2210619449615479 Accuracy : 0.515625
# Iteration 180 of epoch 5 complete. Loss : 1.1717143058776855 Accuracy : 0.546875
# Iteration 190 of epoch 5 complete. Loss : 1.1232225894927979 Accuracy : 0.5625
# Iteration 200 of epoch 5 complete. Loss : 1.2224454879760742 Accuracy : 0.515625
# Iteration 210 of epoch 5 complete. Loss : 1.2388858795166016 Accuracy : 0.546875
# Iteration 220 of epoch 5 complete. Loss : 1.2550793886184692 Accuracy : 0.40625
# Iteration 230 of epoch 5 complete. Loss : 1.1854627132415771 Accuracy : 0.546875
#  Validation Accuracy : 0.4741268754005432, Validation Loss : 1.2654823064804077
# EPOCH:  6
# Iteration 10 of epoch 6 complete. Loss : 1.328768014907837 Accuracy : 0.34375
# Iteration 20 of epoch 6 complete. Loss : 1.1993675231933594 Accuracy : 0.46875
# Iteration 30 of epoch 6 complete. Loss : 1.2533131837844849 Accuracy : 0.46875
# Iteration 40 of epoch 6 complete. Loss : 1.2696285247802734 Accuracy : 0.484375
# Iteration 50 of epoch 6 complete. Loss : 1.3514429330825806 Accuracy : 0.5
# Iteration 60 of epoch 6 complete. Loss : 1.1210907697677612 Accuracy : 0.53125
# Iteration 70 of epoch 6 complete. Loss : 1.3480275869369507 Accuracy : 0.4375
# Iteration 80 of epoch 6 complete. Loss : 1.3216389417648315 Accuracy : 0.4375
# Iteration 90 of epoch 6 complete. Loss : 1.327272891998291 Accuracy : 0.359375
# Iteration 100 of epoch 6 complete. Loss : 1.2559806108474731 Accuracy : 0.46875
# Iteration 110 of epoch 6 complete. Loss : 1.1990305185317993 Accuracy : 0.484375
# Iteration 120 of epoch 6 complete. Loss : 1.1133835315704346 Accuracy : 0.578125
# Iteration 130 of epoch 6 complete. Loss : 1.3140157461166382 Accuracy : 0.5
# Iteration 140 of epoch 6 complete. Loss : 1.2126810550689697 Accuracy : 0.421875
# Iteration 150 of epoch 6 complete. Loss : 1.2891849279403687 Accuracy : 0.4375
# Iteration 160 of epoch 6 complete. Loss : 1.250470519065857 Accuracy : 0.46875
# Iteration 170 of epoch 6 complete. Loss : 1.2072570323944092 Accuracy : 0.5
# Iteration 180 of epoch 6 complete. Loss : 1.1527799367904663 Accuracy : 0.53125
# Iteration 190 of epoch 6 complete. Loss : 1.1009697914123535 Accuracy : 0.5625
# Iteration 200 of epoch 6 complete. Loss : 1.2031313180923462 Accuracy : 0.53125
# Iteration 210 of epoch 6 complete. Loss : 1.2263355255126953 Accuracy : 0.5625
# Iteration 220 of epoch 6 complete. Loss : 1.2357640266418457 Accuracy : 0.40625
# Iteration 230 of epoch 6 complete. Loss : 1.1644219160079956 Accuracy : 0.5625
#  Validation Accuracy : 0.48000383377075195, Validation Loss : 1.2518987655639648
# EPOCH:  7
# Iteration 10 of epoch 7 complete. Loss : 1.312324047088623 Accuracy : 0.359375
# Iteration 20 of epoch 7 complete. Loss : 1.1809686422348022 Accuracy : 0.484375
# Iteration 30 of epoch 7 complete. Loss : 1.2349772453308105 Accuracy : 0.46875
# Iteration 40 of epoch 7 complete. Loss : 1.2580393552780151 Accuracy : 0.5
# Iteration 50 of epoch 7 complete. Loss : 1.3413934707641602 Accuracy : 0.5
# Iteration 60 of epoch 7 complete. Loss : 1.1025217771530151 Accuracy : 0.53125
# Iteration 70 of epoch 7 complete. Loss : 1.3368834257125854 Accuracy : 0.4375
# Iteration 80 of epoch 7 complete. Loss : 1.306694507598877 Accuracy : 0.453125
# Iteration 90 of epoch 7 complete. Loss : 1.3169916868209839 Accuracy : 0.375
# Iteration 100 of epoch 7 complete. Loss : 1.242027997970581 Accuracy : 0.453125
# Iteration 110 of epoch 7 complete. Loss : 1.1839039325714111 Accuracy : 0.484375
# Iteration 120 of epoch 7 complete. Loss : 1.0997893810272217 Accuracy : 0.578125
# Iteration 130 of epoch 7 complete. Loss : 1.3014105558395386 Accuracy : 0.5
# Iteration 140 of epoch 7 complete. Loss : 1.200182318687439 Accuracy : 0.4375
# Iteration 150 of epoch 7 complete. Loss : 1.278227686882019 Accuracy : 0.421875
# Iteration 160 of epoch 7 complete. Loss : 1.2377347946166992 Accuracy : 0.4375
# Iteration 170 of epoch 7 complete. Loss : 1.1974576711654663 Accuracy : 0.5
# Iteration 180 of epoch 7 complete. Loss : 1.138403058052063 Accuracy : 0.53125
# Iteration 190 of epoch 7 complete. Loss : 1.083694338798523 Accuracy : 0.578125
# Iteration 200 of epoch 7 complete. Loss : 1.1875784397125244 Accuracy : 0.53125
# Iteration 210 of epoch 7 complete. Loss : 1.2164275646209717 Accuracy : 0.546875
# Iteration 220 of epoch 7 complete. Loss : 1.2202140092849731 Accuracy : 0.375
# Iteration 230 of epoch 7 complete. Loss : 1.1473207473754883 Accuracy : 0.578125
#  Validation Accuracy : 0.4803072512149811, Validation Loss : 1.241499900817871
# EPOCH:  8
# Iteration 10 of epoch 8 complete. Loss : 1.2989000082015991 Accuracy : 0.328125
# Iteration 20 of epoch 8 complete. Loss : 1.1664351224899292 Accuracy : 0.484375
# Iteration 30 of epoch 8 complete. Loss : 1.220542073249817 Accuracy : 0.46875
# Iteration 40 of epoch 8 complete. Loss : 1.2494442462921143 Accuracy : 0.546875
# Iteration 50 of epoch 8 complete. Loss : 1.333324670791626 Accuracy : 0.46875
# Iteration 60 of epoch 8 complete. Loss : 1.0880416631698608 Accuracy : 0.546875
# Iteration 70 of epoch 8 complete. Loss : 1.3275904655456543 Accuracy : 0.453125
# Iteration 80 of epoch 8 complete. Loss : 1.294853687286377 Accuracy : 0.453125
# Iteration 90 of epoch 8 complete. Loss : 1.3088462352752686 Accuracy : 0.375
# Iteration 100 of epoch 8 complete. Loss : 1.2303545475006104 Accuracy : 0.4375
# Iteration 110 of epoch 8 complete. Loss : 1.172479510307312 Accuracy : 0.484375
# Iteration 120 of epoch 8 complete. Loss : 1.0896552801132202 Accuracy : 0.59375
# Iteration 130 of epoch 8 complete. Loss : 1.291383147239685 Accuracy : 0.5
# Iteration 140 of epoch 8 complete. Loss : 1.190094232559204 Accuracy : 0.453125
# Iteration 150 of epoch 8 complete. Loss : 1.2692497968673706 Accuracy : 0.4375
# Iteration 160 of epoch 8 complete. Loss : 1.227347493171692 Accuracy : 0.4375
# Iteration 170 of epoch 8 complete. Loss : 1.19023859500885 Accuracy : 0.515625
# Iteration 180 of epoch 8 complete. Loss : 1.1270089149475098 Accuracy : 0.53125
# Iteration 190 of epoch 8 complete. Loss : 1.069726824760437 Accuracy : 0.578125
# Iteration 200 of epoch 8 complete. Loss : 1.1746323108673096 Accuracy : 0.53125
# Iteration 210 of epoch 8 complete. Loss : 1.208272099494934 Accuracy : 0.5625
# Iteration 220 of epoch 8 complete. Loss : 1.2073545455932617 Accuracy : 0.390625
# Iteration 230 of epoch 8 complete. Loss : 1.1330960988998413 Accuracy : 0.578125
#  Validation Accuracy : 0.4830378293991089, Validation Loss : 1.2332619428634644
# EPOCH:  9
# Iteration 10 of epoch 9 complete. Loss : 1.2876322269439697 Accuracy : 0.328125
# Iteration 20 of epoch 9 complete. Loss : 1.1546342372894287 Accuracy : 0.46875
# Iteration 30 of epoch 9 complete. Loss : 1.2088998556137085 Accuracy : 0.46875
# Iteration 40 of epoch 9 complete. Loss : 1.2428268194198608 Accuracy : 0.546875
# Iteration 50 of epoch 9 complete. Loss : 1.3265929222106934 Accuracy : 0.46875
# Iteration 60 of epoch 9 complete. Loss : 1.0764051675796509 Accuracy : 0.53125
# Iteration 70 of epoch 9 complete. Loss : 1.3196269273757935 Accuracy : 0.453125
# Iteration 80 of epoch 9 complete. Loss : 1.2852195501327515 Accuracy : 0.4375
# Iteration 90 of epoch 9 complete. Loss : 1.3021183013916016 Accuracy : 0.390625
# Iteration 100 of epoch 9 complete. Loss : 1.2203869819641113 Accuracy : 0.4375
# Iteration 110 of epoch 9 complete. Loss : 1.1636004447937012 Accuracy : 0.515625
# Iteration 120 of epoch 9 complete. Loss : 1.0818147659301758 Accuracy : 0.59375
# Iteration 130 of epoch 9 complete. Loss : 1.283151626586914 Accuracy : 0.5
# Iteration 140 of epoch 9 complete. Loss : 1.1816637516021729 Accuracy : 0.4375
# Iteration 150 of epoch 9 complete. Loss : 1.2616212368011475 Accuracy : 0.4375
# Iteration 160 of epoch 9 complete. Loss : 1.2186076641082764 Accuracy : 0.453125
# Iteration 170 of epoch 9 complete. Loss : 1.1847658157348633 Accuracy : 0.515625
# Iteration 180 of epoch 9 complete. Loss : 1.1176846027374268 Accuracy : 0.515625
# Iteration 190 of epoch 9 complete. Loss : 1.0580646991729736 Accuracy : 0.578125
# Iteration 200 of epoch 9 complete. Loss : 1.1636037826538086 Accuracy : 0.53125
# Iteration 210 of epoch 9 complete. Loss : 1.2013521194458008 Accuracy : 0.5625
# Iteration 220 of epoch 9 complete. Loss : 1.1964956521987915 Accuracy : 0.390625
# Iteration 230 of epoch 9 complete. Loss : 1.1210607290267944 Accuracy : 0.578125
#  Validation Accuracy : 0.4828861355781555, Validation Loss : 1.2265634536743164
# EPOCH:  10
# Iteration 10 of epoch 10 complete. Loss : 1.2779858112335205 Accuracy : 0.328125
# Iteration 20 of epoch 10 complete. Loss : 1.1448543071746826 Accuracy : 0.453125
# Iteration 30 of epoch 10 complete. Loss : 1.1993340253829956 Accuracy : 0.484375
# Iteration 40 of epoch 10 complete. Loss : 1.237572193145752 Accuracy : 0.53125
# Iteration 50 of epoch 10 complete. Loss : 1.3208189010620117 Accuracy : 0.46875
# Iteration 60 of epoch 10 complete. Loss : 1.0668365955352783 Accuracy : 0.53125
# Iteration 70 of epoch 10 complete. Loss : 1.3126674890518188 Accuracy : 0.453125
# Iteration 80 of epoch 10 complete. Loss : 1.2772154808044434 Accuracy : 0.40625
# Iteration 90 of epoch 10 complete. Loss : 1.296371579170227 Accuracy : 0.375
# Iteration 100 of epoch 10 complete. Loss : 1.2117573022842407 Accuracy : 0.4375
# Iteration 110 of epoch 10 complete. Loss : 1.1565338373184204 Accuracy : 0.53125
# Iteration 120 of epoch 10 complete. Loss : 1.0755555629730225 Accuracy : 0.59375
# Iteration 130 of epoch 10 complete. Loss : 1.2762207984924316 Accuracy : 0.5
# Iteration 140 of epoch 10 complete. Loss : 1.1744351387023926 Accuracy : 0.4375
# Iteration 150 of epoch 10 complete. Loss : 1.2549611330032349 Accuracy : 0.4375
# Iteration 160 of epoch 10 complete. Loss : 1.2110772132873535 Accuracy : 0.46875
# Iteration 170 of epoch 10 complete. Loss : 1.1805213689804077 Accuracy : 0.515625
# Iteration 180 of epoch 10 complete. Loss : 1.1098673343658447 Accuracy : 0.515625
# Iteration 190 of epoch 10 complete. Loss : 1.0480746030807495 Accuracy : 0.5625
# Iteration 200 of epoch 10 complete. Loss : 1.1540510654449463 Accuracy : 0.53125
# Iteration 210 of epoch 10 complete. Loss : 1.1953421831130981 Accuracy : 0.5625
# Iteration 220 of epoch 10 complete. Loss : 1.1871716976165771 Accuracy : 0.40625
# Iteration 230 of epoch 10 complete. Loss : 1.1107404232025146 Accuracy : 0.578125
#  Validation Accuracy : 0.4862234890460968, Validation Loss : 1.221002221107483

# %% [markdown]
# ## Testing

# %%
test_acc, test_loss = evaluate(net, loss_func, test_loader)
print(" Test Accuracy : {}, Test Loss (Cross entropy) : {}".format(test_acc, test_loss))
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2291: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
#  Test Accuracy : 0.4737866520881653, Test Loss (Cross entropy) : 1.2131178379058838

# %%
torch.save(net.state_dict(), "/content/drive/MyDrive/weight.pth")
